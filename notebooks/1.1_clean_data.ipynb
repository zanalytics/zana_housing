# %% [markdown]
# #### Clean Data Notebook
#
# 1. Rename the columns
# 2. Irrelevant columns
# 3. Duplicates
# 4. Null Values in relevant columns
# 5. Outliers
# 6. Map column values
# 7. Visualise and investigate

# %%
import pandas as pd

# %%
column_names = ['id', 'price', 'date', 'postcode', 
        'type', 'new_build', 'land', 'primary_address', 
        'secondary_address', 'street', 'locality', 'town_city', 
        'district', 'county', 'ppd', 'record' ]

df = pd.read_csv("../data/raw/pp-complete.csv", names = column_names, parse_dates = ['date'])

# %%
df.head(5)

# %%
df.type.value_counts()

# %%
print(f"The data contains {df.shape[0]} rows.")

# %%
df.dtypes

# %%
# Since we know the id's are not duplicated we can search excluding the id to see if any houses are entered twice.
duplicates = df.loc[:, 'price':'record'][df.loc[:, 'price':'record'].duplicated()]
print(f"The number of duplicates excluding id is {duplicates.shape[0]}")

# %%
#Lets perfom a quick check to verify there are actually duplicates (The answer should be two observations)
#df[(df['postcode']=='') & (df['primary_address']=='')]

# %%
# Lets drop the duplicates, keeping only the first instance. 
df_no_duplicates = df.drop_duplicates(subset = df.columns[1:] , keep = "first")

# %%
#Lets check the number of empty rows in each column. 
df_no_duplicates.isnull().sum()

# %%
df_empty_postcodes = df_no_duplicates[df_no_duplicates['postcode'].isnull()]

# %%
df_empty_postcodes.head()

# %%
#Difficult decision - we can obviously try and workout a way to get the postcode using the roads but 
#that can prove to be too much work for us
#For now let us delete the observations with no postcode. 
df_complete = df_no_duplicates[df_no_duplicates['postcode'].notnull()]

# %%
df_complete.shape[0]

# %%
#Lets view the range of the data (10 largest and 10 smallest)
df_complete.nlargest(n=10, columns='price')

# %% [markdown]
# I think we can all admit - we can't afford these kind of houses. I really wanted to make this project for a normal ordinary house. So what I really want to do is to cap the data to just houses that are less than a million.

# %%
# Lets View the cheaperst houses. 
df_complete.nsmallest(n=10, columns='price')

# %%
# From this I think we should only observe houses that are between 10,000 and 1,000,000
df_price_cut = df_complete[(df_complete['price']<=1000000) & (df['price']>=10000)].reset_index(drop = True)
# Out:
# <ipython-input-6-3d3e9660becf>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_price_cut = df_complete[(df_complete['price']<=1000000) & (df['price']>=10000)].reset_index(drop = True)

# %%
perc_reduction = ((df_complete.shape[0] - df_price_cut.shape[0])/df_complete.shape[0])*100
print(f"filtered out {perc_reduction} % of data")

# %%
df_price_cut.to_csv("../data/processed/house_1_price_cut.csv", index = False)

# %%
# Going forward we need to add some columns

# %%
new_build = {'Y': 1,'N': 0}
df_price_cut.new_build = [new_build[item] for item in df_price_cut.new_build]
df_price_cut['year'] = df_price_cut['date'].dt.year
df_price_cut['month'] = df_price_cut['date'].dt.year
df_price_cut['month_year'] = df_price_cut['date'].astype('datetime64[M]')

# %%
df_price_cut.head()

# %%
df_price_cut = df_price_cut.drop(columns=['locality','town_city','district','county'])

# %%
df_price_cut.columns

# %% [markdown]
# ## I GOT IT WRONG

# %%
#Adjust price to inflation
df_multiplier = pd.read_csv("../data/raw/inflation_multiplier.csv", usecols = ['Year', 'Multiplier'], dtype = {'Year': 'int64', 'Multiplier': 'float64'})
df_multiplier.columns =['year', 'multiplier']

# %%
df_multiplier.dtypes

# %%
df_multiplier

# %% [raw]
# df_house_data = pd.merge(df_price_cut, df_multiplier, on='year')

# %% [raw]
# df_house_data['adjusted_price'] = df_house_data['price'] * df_house_data['multiplier']

# %% [raw]
# df_house_data.head()

# %% [raw]
# df_house_data.nlargest(n=10, columns='adjusted_price')

# %% [raw]
# df_house_data.to_csv("../data/processed/house_2_adjusted_data.csv", index = False)

# %% [markdown]
# ## Read in the house price index data

# %%
df_house_index = pd.read_csv("http://publicdata.landregistry.gov.uk/market-trend-data/house-price-index-data/Average-prices-Property-Type-2020-08.csv?utm_medium=GOV.UK&utm_source=datadownload&utm_campaign=average_price_property_price&utm_term=9.30_21_10_20")
df_house_index.columns = map(str.lower, df_house_index.columns)
df_house_index.columns = df_house_index.columns.str.replace(' ', '_')

# %%
df_house_index.head()

# %%
df_house_index = df_house_index.drop(columns=df_house_index.columns[df_house_index.columns.str.contains(pat = 'change|price')])

# %%
df_house_index.head()

# %%
df_house_index.dtypes
df_house_index['date'] = pd.to_datetime(df_house_index['date'])

# %%
df_house_index.nlargest(n=10, columns='date')

# %%
df_house_index[df_house_index['semi_detached_index'].isnull()]

# %%
df_house_index.shape

# %% [markdown]
# ## Read in the postcode data

# %%
df_postcode = pd.read_csv("../data/raw/postcodes.csv")
# Out:
# /Users/chris/Documents/projects/github/zanalytics/zana_housing/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (7,17,18,21,22,24,25,29,32,39,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_postcode.columns = map(str.lower, df_postcode.columns)
df_postcode.columns = df_postcode.columns.str.replace(' ', '_')

# %%
df_postcode.columns

# %%
df_postcode = df_postcode[['postcode', 'latitude', 'longitude',
       'grid_ref', 'county', 'district', 'ward', 'district_code', 'ward_code',
       'county_code', 'constituency', 'region', 'london_zone', 
        'middle_layer_super_output_area', 'postcode_area', 'postcode_district']]

# %%
df_postcode.columns

# %%
df_area_info = pd.merge(df_price_cut, df_postcode, on='postcode')

# %%
df_area_info.head()

# %%
df_area_info.isnull().sum()

# %%
df_house_complete_district_1 = pd.merge(df_area_info, df_house_index, how='left', left_on=['district_code','month_year'], right_on=['area_code', 'date'])

# %%
df_house_complete_district = pd.merge(df_area_info, df_house_index, how='left', left_on=['county_code','month_year'], right_on=['area_code', 'date'])

# %%
df_house_complete_district_1.isnull().sum()
# Out:
# id                                       0
# price                                    0
# date_x                                   0
# postcode                                 0
# type                                     0
# new_build                                0
# land                                     0
# primary_address                       4181
# secondary_address                 22238432
# street                              376717
# ppd                                      0
# record                                   0
# year                                     0
# month                                    0
# month_year                               0
# latitude                                 0
# longitude                                0
# grid_ref                                 0
# county                             1436433
# district                                 0
# ward                                     0
# district_code                            0
# ward_code                                0
# county_code                              0
# constituency                             0
# region                             1195134
# london_zone                       21972013
# middle_layer_super_output_area           0
# postcode_area                            0
# postcode_district                        0
# date_y                              241860
# region_name                         241860
# area_code                           241860
# detached_index                      249269
# semi_detached_index                 249269
# terraced_index                      248848
# flat_index                          241860
# dtype: int64

# %%
df_house_complete_district.isnull().sum()
# Out:
# id                                       0
# price                                    0
# date_x                                   0
# postcode                                 0
# type                                     0
# new_build                                0
# land                                     0
# primary_address                       4181
# secondary_address                 22238432
# street                              376717
# ppd                                      0
# record                                   0
# year                                     0
# month                                    0
# month_year                               0
# latitude                                 0
# longitude                                0
# grid_ref                                 0
# county                             1436433
# district                                 0
# ward                                     0
# district_code                            0
# ward_code                                0
# county_code                              0
# constituency                             0
# region                             1195134
# london_zone                       21972013
# middle_layer_super_output_area           0
# postcode_area                            0
# postcode_district                        0
# date_y                            11187976
# region_name                       11187976
# area_code                         11187976
# detached_index                    11187976
# semi_detached_index               11187976
# terraced_index                    11187976
# flat_index                        11187976
# dtype: int64

# %%
df_house_complete_district.isnull().sum()

# %%
df_house_complete = df_house_complete_district_1

# %%
df_house_complete.head()
# Out:
#                                        id   price     date_x postcode type  \
# 0  {A42E2F04-2538-4A25-94C5-49E29C6C8FA8}   18500 1995-01-31  TQ1 1RY    F
# 1  {08A8FE57-2C42-40DE-9C33-E8D7D8A9CEBB}   18000 1995-09-07  TQ1 1RY    F
# 2  {10BE69F8-64A5-4FD7-A172-B4448FBC44EB}   19000 1995-04-28  TQ1 1RY    F
# 3  {2A289EA0-040F-CDC8-E050-A8C063054829}  300000 1995-01-09  TQ1 1RY    F
# 4  {01178325-E934-4283-A908-06DBE03D1E16}   28500 1995-11-30  TQ1 1RY    F
#
#    new_build land primary_address secondary_address                street  \
# 0          0    L  VILLA PARADISO           FLAT 10  HIGHER WARBERRY ROAD
# 1          0    L  VILLA PARADISO            FLAT 4  HIGHER WARBERRY ROAD
# 2          0    L  VILLA PARADISO            FLAT 3  HIGHER WARBERRY ROAD
# 3          0    F  ROSA PINES LTD               NaN  HIGHER WARBERRY ROAD
# 4          0    L  VILLA PARADISO            FLAT 3  HIGHER WARBERRY ROAD
#
#    ... middle_layer_super_output_area postcode_area  postcode_district  \
# 0  ...                      Wellswood            TQ                TQ1
# 1  ...                      Wellswood            TQ                TQ1
# 2  ...                      Wellswood            TQ                TQ1
# 3  ...                      Wellswood            TQ                TQ1
# 4  ...                      Wellswood            TQ                TQ1
#
#       date_y region_name  area_code  detached_index semi_detached_index  \
# 0 1995-01-01      Torbay  E06000027       29.473651           28.476256
# 1 1995-09-01      Torbay  E06000027       29.808396           28.975339
# 2 1995-04-01      Torbay  E06000027       29.160153           28.678533
# 3 1995-01-01      Torbay  E06000027       29.473651           28.476256
# 4 1995-11-01      Torbay  E06000027       29.393848           28.605845
#
#   terraced_index flat_index
# 0      27.784074  31.723504
# 1      28.191223  31.658162
# 2      27.951063  31.760541
# 3      27.784074  31.723504
# 4      27.536689  31.458432
#
# [5 rows x 37 columns]

# %%
df_house_complete = df_house_complete.drop(columns=['date_y'])
df_house_complete = df_house_complete.rename({'date_x': 'date'}, axis='columns')

# %%
df_house_complete['p_average_index'] = df_house_complete[['p_detached_index','p_semi_detached_index','p_terraced_index','p_flat_index']].mean(axis=1)

# %%
df_house_complete.head()

# %%
from datetime import datetime
import dateutil.relativedelta

df_house_complete['current_month'] = pd.to_datetime(datetime.today().date().replace(day=1)) - dateutil.relativedelta.relativedelta(months=3)

# %%
df_house_complete = df_house_complete.rename({'date': 'transaction_date',
                                             'detached_index':'p_detached_index',
                                              'semi_detached_index':'p_semi_detached_index',
                                              'terraced_index':'p_terraced_index',
                                              'flat_index':'p_flat_index',
                                              'average_index':'p_average_index'
                                             }, axis='columns')

# %%
df_house_complete_joined = pd.merge(df_house_complete, df_house_index, how='left', left_on=['district_code','current_month'], right_on=['area_code', 'date'])

# %%
#df_house_complete = pd.merge(df_house_complete, df_house_index, how='left', left_on=['district_code','current_month'], right_on=['area_code', 'date'])

# %%
dummy_df_house_complete.isnull().sum()

# %%
df_house_complete_joined['current_average_index'] = df_house_complete_joined[['detached_index','semi_detached_index','terraced_index','flat_index']].mean(axis=1)

# %%
df_house_complete = df_house_complete_joined

# %%
df_house_complete.columns
# Out:
# Index(['id', 'price', 'date_x', 'postcode', 'type', 'new_build', 'land',
#        'primary_address', 'secondary_address', 'street', 'ppd', 'record',
#        'year', 'month', 'month_year', 'latitude', 'longitude', 'grid_ref',
#        'county', 'district', 'ward', 'district_code', 'ward_code',
#        'county_code', 'constituency', 'region', 'london_zone',
#        'middle_layer_super_output_area', 'postcode_area', 'postcode_district',
#        'date_y', 'region_name_x', 'area_code_x', 'p_detached_index',
#        'p_semi_detached_index', 'p_terraced_index', 'p_flat_index',
#        'current_month', 'date', 'region_name_y', 'area_code_y',
#        'detached_index', 'semi_detached_index', 'terraced_index', 'flat_index',
#        'current_average_index', 'adjusted_price', 'p_average_index'],
#       dtype='object')

# %%
df_house_complete.loc[df_house_complete['type'] == 'T', 'adjusted_price'] = (df_house_complete['terraced_index']/df_house_complete['p_terraced_index']) * df_house_complete['price']
df_house_complete.loc[df_house_complete['type'] == 'S', 'adjusted_price'] = (df_house_complete['semi_detached_index']/df_house_complete['p_semi_detached_index']) * df_house_complete['price']
df_house_complete.loc[df_house_complete['type'] == 'D', 'adjusted_price'] = (df_house_complete['detached_index']/df_house_complete['p_detached_index']) * df_house_complete['price']
df_house_complete.loc[df_house_complete['type'] == 'F', 'adjusted_price'] = (df_house_complete['flat_index']/df_house_complete['p_flat_index']) * df_house_complete['price']
df_house_complete.loc[df_house_complete['type'] == 'O', 'adjusted_price'] = (df_house_complete['current_average_index']/df_house_complete['p_average_index']) * df_house_complete['price']

# %%
df_house_complete.isnull().sum()
# Out:
# id                                       0
# price                                    0
# date_x                                   0
# postcode                                 0
# type                                     0
# new_build                                0
# land                                     0
# primary_address                       4181
# secondary_address                 22238432
# street                              376717
# ppd                                      0
# record                                   0
# year                                     0
# month                                    0
# month_year                               0
# latitude                                 0
# longitude                                0
# grid_ref                                 0
# county                             1436433
# district                                 0
# ward                                     0
# district_code                            0
# ward_code                                0
# county_code                              0
# constituency                             0
# region                             1195134
# london_zone                       21972013
# middle_layer_super_output_area           0
# postcode_area                            0
# postcode_district                        0
# date_y                              241860
# region_name_x                       241860
# area_code_x                         241860
# p_detached_index                    249269
# p_semi_detached_index               249269
# p_terraced_index                    248848
# p_flat_index                        241860
# current_month                            0
# date                                241858
# region_name_y                       241858
# area_code_y                         241858
# detached_index                      249267
# semi_detached_index                 249267
# terraced_index                      249267
# flat_index                          241858
# current_average_index               241858
# adjusted_price                      241931
# p_average_index                     241860
# dtype: int64

# %%
df_house_complete[df_house_complete['adjusted_price'].isnull()].head(20)

# %%
df_house_complete.shape

# %%
df_house_complete_nn = df_house_complete[df_house_complete['adjusted_price'].notnull()]

# %%
df_house_complete_nn['adjusted_price'] = df_house_complete_nn['adjusted_price'].astype(int)
# Out:
# <ipython-input-55-b3fa61558082>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_complete_nn['adjusted_price'] = df_house_complete_nn['adjusted_price'].astype(int)

# %%
df_house_complete_nn.shape
# Out:
# (24899926, 48)

# %%
df_house_complete_nn.columns
# Out:
# Index(['id', 'price', 'date_x', 'postcode', 'type', 'new_build', 'land',
#        'primary_address', 'secondary_address', 'street', 'ppd', 'record',
#        'year', 'month', 'month_year', 'latitude', 'longitude', 'grid_ref',
#        'county', 'district', 'ward', 'district_code', 'ward_code',
#        'county_code', 'constituency', 'region', 'london_zone',
#        'middle_layer_super_output_area', 'postcode_area', 'postcode_district',
#        'date_y', 'region_name_x', 'area_code_x', 'p_detached_index',
#        'p_semi_detached_index', 'p_terraced_index', 'p_flat_index',
#        'current_month', 'date', 'region_name_y', 'area_code_y',
#        'detached_index', 'semi_detached_index', 'terraced_index', 'flat_index',
#        'current_average_index', 'adjusted_price', 'p_average_index'],
#       dtype='object')

# %%
df_house_complete_nn = df_house_complete_nn.drop(columns=['p_detached_index','p_semi_detached_index', 'p_terraced_index', 
                                                                                      'p_flat_index','current_month', 'date', 'region_name_y', 'area_code_y',
                                                                                       'detached_index', 'semi_detached_index', 'terraced_index', 'flat_index',
                                                                                       'current_average_index', 'p_average_index'])

# %%
df_house_complete_nn.head()
# Out:
#                                        id   price     date_x postcode type  \
# 0  {A42E2F04-2538-4A25-94C5-49E29C6C8FA8}   18500 1995-01-31  TQ1 1RY    F
# 1  {08A8FE57-2C42-40DE-9C33-E8D7D8A9CEBB}   18000 1995-09-07  TQ1 1RY    F
# 2  {10BE69F8-64A5-4FD7-A172-B4448FBC44EB}   19000 1995-04-28  TQ1 1RY    F
# 3  {2A289EA0-040F-CDC8-E050-A8C063054829}  300000 1995-01-09  TQ1 1RY    F
# 4  {01178325-E934-4283-A908-06DBE03D1E16}   28500 1995-11-30  TQ1 1RY    F
#
#    new_build land primary_address secondary_address                street  \
# 0          0    L  VILLA PARADISO           FLAT 10  HIGHER WARBERRY ROAD
# 1          0    L  VILLA PARADISO            FLAT 4  HIGHER WARBERRY ROAD
# 2          0    L  VILLA PARADISO            FLAT 3  HIGHER WARBERRY ROAD
# 3          0    F  ROSA PINES LTD               NaN  HIGHER WARBERRY ROAD
# 4          0    L  VILLA PARADISO            FLAT 3  HIGHER WARBERRY ROAD
#
#    ... constituency      region  london_zone  middle_layer_super_output_area  \
# 0  ...       Torbay  South West          NaN                       Wellswood
# 1  ...       Torbay  South West          NaN                       Wellswood
# 2  ...       Torbay  South West          NaN                       Wellswood
# 3  ...       Torbay  South West          NaN                       Wellswood
# 4  ...       Torbay  South West          NaN                       Wellswood
#
#   postcode_area  postcode_district     date_y region_name_x area_code_x  \
# 0            TQ                TQ1 1995-01-01        Torbay   E06000027
# 1            TQ                TQ1 1995-09-01        Torbay   E06000027
# 2            TQ                TQ1 1995-04-01        Torbay   E06000027
# 3            TQ                TQ1 1995-01-01        Torbay   E06000027
# 4            TQ                TQ1 1995-11-01        Torbay   E06000027
#
# 11700768  {8979629D-204F-46B0-B38B-98008758E6F7}  242500 2009-07-31  S12 4WX
# 11700769  {DB32B08A-D8A1-440A-9D03-429A71A59581}   80000 2010-05-24  S12 4WX
# 11700770  {4FA47CD4-D9BD-4B09-AC41-305E956B3029}  249950 2011-09-08  S12 4WX
# 11700771  {DAD7B40B-D2A4-4F7E-B188-071845EAED5A}   84995 2012-03-29  S12 4WX
# 11700772  {07563753-8FC8-46DC-AD32-DAD83CFBB140}  165000 2013-10-28  S12 4WX
# 11700773  {73F4F5DA-D397-455E-9755-2B060F365940}   39000 2013-03-08  S12 4WX
# 11700774  {21E5FEB7-1874-2439-E050-A8C06205342E}  170000 2013-10-25  S12 4WX
# 11700775  {CCF1B189-85C2-4DFA-9B64-FB8AC6BE9947}  124950 2014-11-28  S12 4WX
# 11700776  {3914047A-3511-3206-E050-A8C063057647}  145000 2016-06-23  S12 4WX
# 11700777  {31FB4C18-02E5-57B9-E050-A8C063053436}   89000 2016-04-08  S12 4WX
# 11700778  {5376B385-FC4C-34C1-E053-6B04A8C09FF6}   73500 2017-04-28  S12 4WX
# 11700779  {5F54B81D-C17C-2B45-E053-6B04A8C01FB0}  300000 2017-10-09  S12 4WX
# 11700780  {61D8894E-5ACF-3DE6-E053-6C04A8C01207}  295000 2017-11-24  S12 4WX
# 11700781  {726BF13B-54D8-0A46-E053-6C04A8C01D0D}  100000 2018-07-06  S12 4WX
# 11700782  {8F1B26BE-3779-53DB-E053-6C04A8C03649}   95500 2019-06-21  S12 4WX
# 11700783  {8355F009-7558-55C5-E053-6B04A8C0D090}   71500 2019-02-08  S12 4WX
# 11700784  {8355F009-756F-55C5-E053-6B04A8C0D090}  160000 2019-01-24  S12 4WX
# 11700785  {9DBAD222-43DB-6EB3-E053-6B04A8C0F257}  170000 2019-06-07  S12 4WX
#
#          type  new_build land primary_address secondary_address  \
# 11700741    S          0    F               3               NaN
# 11700742    F          0    L              20               NaN
# 11700743    F          0    L              18               NaN
# 11700744    F          0    L              36               NaN
# 11700745    T          0    F               1               NaN
# 11700746    F          0    L              38               NaN
# 11700747    T          0    F               1               NaN
# 11700748    S          0    F               5               NaN
# 11700749    S          0    L              24               NaN
# 11700750    D          0    L              40               NaN
# 11700751    D          0    F               9               NaN
# 11700752    S          0    F               3               NaN
# 11700753    S          0    F               7               NaN
# 11700754    T          0    L              32               NaN
# 11700755    D          0    F              48               NaN
# 11700756    D          1    F              52               NaN
# 11700757    F          0    L              30               NaN
# 11700758    F          0    L              22               NaN
# 11700759    D          1    F              46               NaN
# 11700760    S          0    F               7               NaN
# 11700761    T          0    L              34               NaN
# 11700762    S          0    F               3               NaN
# 11700763    S          0    F               5               NaN
# 11700764    S          0    L              24               NaN
# 11700765    D          0    F              50               NaN
# 11700766    S          0    F               3               NaN
# 11700767    D          1    F              15               NaN
# 11700768    D          0    F              52               NaN
# 11700769    T          0    L              34               NaN
# 11700770    D          0    F              46               NaN
# 11700771    F          0    L              34               NaN
# 11700772    D          0    L              40               NaN
# 11700773    F          0    L              16               NaN
# 11700752                S12 2003-06-01     Sheffield   E08000019
# 11700753                S12 2003-06-01     Sheffield   E08000019
# 11700754                S12 2004-12-01     Sheffield   E08000019
# 11700755                S12 2004-09-01     Sheffield   E08000019
# 11700756                S12 2004-12-01     Sheffield   E08000019
# 11700757                S12 2004-04-01     Sheffield   E08000019
# 11700758                S12 2004-10-01     Sheffield   E08000019
# 11700759                S12 2004-05-01     Sheffield   E08000019
# 11700760                S12 2005-09-01     Sheffield   E08000019
# 11700761                S12 2005-09-01     Sheffield   E08000019
# 11700762                S12 2005-11-01     Sheffield   E08000019
# 11700763                S12 2006-02-01     Sheffield   E08000019
# 11700764                S12 2007-11-01     Sheffield   E08000019
# 11700765                S12 2007-10-01     Sheffield   E08000019
# 11700766                S12 2007-07-01     Sheffield   E08000019
# 11700767                S12 2007-04-01     Sheffield   E08000019
# 11700768                S12 2009-07-01     Sheffield   E08000019
# 11700769                S12 2010-05-01     Sheffield   E08000019
# 11700770                S12 2011-09-01     Sheffield   E08000019
# 11700771                S12 2012-03-01     Sheffield   E08000019
# 11700772                S12 2013-10-01     Sheffield   E08000019
# 11700773                S12 2013-03-01     Sheffield   E08000019
# 11700774                S12 2013-10-01     Sheffield   E08000019
# 11700775                S12 2014-11-01     Sheffield   E08000019
# 11700776                S12 2016-06-01     Sheffield   E08000019
# 11700777                S12 2016-04-01     Sheffield   E08000019
# 11700778                S12 2017-04-01     Sheffield   E08000019
# 11700779                S12 2017-10-01     Sheffield   E08000019
# 11700780                S12 2017-11-01     Sheffield   E08000019
# 11700781                S12 2018-07-01     Sheffield   E08000019
# 11700782                S12 2019-06-01     Sheffield   E08000019
# 11700783                S12 2019-02-01     Sheffield   E08000019
# 11700784                S12 2019-01-01     Sheffield   E08000019
# 11700785                S12 2019-06-01     Sheffield   E08000019
#
#          adjusted_price
# 11700741         189822
# 11700742         130387
# 11700743         120986
# 11700744         116371
# 11700745         218662
# 11700746          61770
# 11700747         191119
# 11700748         198382
# 11700749          77401
# 11700750         283362
# 11700751         275557
# 11700752         187464
# 11700753         181073
# 11700754          78748
# 11700755         368609
# 11700756         377647
# 11700757          62620
# 11700758          68090
# 11700759         250086
# 11700760         167582
# 11700761         115852
# 11700762         180181
# 11700763         154018
# 11700764          92050
# 11700765         345501
# 11700766         180148
# 11700767         322244
# 11700768         348693
# 11700769         105276
# 11700770         338153
# 11700771         107520
# 11700772         217144
# 11700773          49234
# 11700774         223724
# 11700775         154235
# 11700776         169015
# 11700777          97587
# 11700778          77692
# 11700779         316060
# 11700780         314258
# 11700781          98861
# 11700782          94093
# 11700783          69688
# 11700784         166804
# 11700785         176082
#
# [45 rows x 34 columns]

# %%
df_house_complete_nn['adjusted_price'] = df_house_complete_nn['adjusted_price'].fillna(0).astype(int)

# %%
df.to_csv("../data/processed/house_4_hpi.csv", index = False)

# %%
df_house_complete[df_house_complete['adjusted_price']== 0].shape[0]

# %%
df_house_complete.head()

# %%
pd.merge(frame_1, frame_2, how='left', left_on='postcode', right_on='postcode')
df_postcode.head()

# %%
pd.set_option('display.max_columns', None)
#df_postcode[df_postcode['postcode']=='NG8 3PA']

# %%
df_multiple_transactions = df_house_data.loc[:, 'postcode':'county'][df_house_data.loc[:, 'postcode':'county'].duplicated()]

# %%
df_multiple_transactions.shape

# %%
# Lets drop the duplicates, keeping only the first instance. 
df_house_data_ordered = df_house_data.sort_values(by=['date'])
df_house_last_sale = df_house_data_ordered.drop_duplicates(subset = df_house_data_ordered.columns[3:14] ,keep = "last")

# %%
df_house_last_sale.shape

# %%
df_house_last_sale.to_csv("../data/processed/house_3_last_sale.csv", index = False)

# %%
df = pd.read_csv("../data/processed/house_4_hpi.csv", parse_dates = ['date_x','date_y'])

# %%
df.head(5)
# Out:
#                                        id   price     date_x postcode type  \
# 0  {A42E2F04-2538-4A25-94C5-49E29C6C8FA8}   18500 1995-01-31  TQ1 1RY    F
# 1  {08A8FE57-2C42-40DE-9C33-E8D7D8A9CEBB}   18000 1995-09-07  TQ1 1RY    F
# 2  {10BE69F8-64A5-4FD7-A172-B4448FBC44EB}   19000 1995-04-28  TQ1 1RY    F
# 3  {2A289EA0-040F-CDC8-E050-A8C063054829}  300000 1995-01-09  TQ1 1RY    F
# 4  {01178325-E934-4283-A908-06DBE03D1E16}   28500 1995-11-30  TQ1 1RY    F
#
#    new_build land primary_address secondary_address                street ppd  \
# 0          0    L  VILLA PARADISO           FLAT 10  HIGHER WARBERRY ROAD   A
# 1          0    L  VILLA PARADISO            FLAT 4  HIGHER WARBERRY ROAD   A
# 2          0    L  VILLA PARADISO            FLAT 3  HIGHER WARBERRY ROAD   A
# 3          0    F  ROSA PINES LTD               NaN  HIGHER WARBERRY ROAD   A
# 4          0    L  VILLA PARADISO            FLAT 3  HIGHER WARBERRY ROAD   A
#
#   record  year  month  month_year   latitude  longitude  grid_ref county  \
# 0      A  1995   1995  1995-01-01  50.467875  -3.519526  SX922642  Devon
# 1      A  1995   1995  1995-09-01  50.467875  -3.519526  SX922642  Devon
# 2      A  1995   1995  1995-04-01  50.467875  -3.519526  SX922642  Devon
# 3      A  1995   1995  1995-01-01  50.467875  -3.519526  SX922642  Devon
# 4      A  1995   1995  1995-11-01  50.467875  -3.519526  SX922642  Devon
#
#   district       ward district_code  ward_code county_code constituency  \
# 0   Torbay  Wellswood     E06000027  E05012269   E10000008       Torbay
# 1   Torbay  Wellswood     E06000027  E05012269   E10000008       Torbay
# 2   Torbay  Wellswood     E06000027  E05012269   E10000008       Torbay
# 3   Torbay  Wellswood     E06000027  E05012269   E10000008       Torbay
# 4   Torbay  Wellswood     E06000027  E05012269   E10000008       Torbay
#
#        region  london_zone middle_layer_super_output_area postcode_area  \
# 0  South West          NaN                      Wellswood            TQ
# 1  South West          NaN                      Wellswood            TQ
# 2  South West          NaN                      Wellswood            TQ
# 3  South West          NaN                      Wellswood            TQ
# 4  South West          NaN                      Wellswood            TQ
#
#   postcode_district     date_y region_name_x area_code_x  adjusted_price
# 0               TQ1 1995-01-01        Torbay   E06000027           67590
# 1               TQ1 1995-09-01        Torbay   E06000027           65899
# 2               TQ1 1995-04-01        Torbay   E06000027           69336
# 3               TQ1 1995-01-01        Torbay   E06000027         1096057
# 4               TQ1 1995-11-01        Torbay   E06000027          105002

# %%
df.shape
# Out:
# (24899926, 29)

# %%
df.shape
# Out:
# (15687273, 29)

# %%
df = df.drop(columns=['record', 'year', 'month', 'date_y', 'area_code_x'])

# %%
df = df.drop_duplicates(subset = ['postcode', 'type', 'new_build', 'land',
                                           'primary_address', 'secondary_address', 'street','latitude', 'longitude', 'grid_ref', 'county', 'district', 'ward',
                                           'district_code', 'ward_code', 'county_code', 'constituency', 'region',
                                           'london_zone', 'middle_layer_super_output_area', 'postcode_area',
                                           'postcode_district'] ,keep = "last")

# %%
df[df['postcode']=='S12 4WX']
# Out:
#                                               id   price     date_x postcode  \
# 11587337  {A75C6563-2ABA-4985-A5E4-89D1E508D2CB}   38500 1999-06-25  S12 4WX
# 11587340  {52E9A25A-7524-4E34-A775-2E3EFD11EC77}   20500 1999-10-29  S12 4WX
# 11587341  {E2514DF3-DDB5-4ED6-8321-0B9B43979F71}   49000 1999-05-28  S12 4WX
# 11587345  {9EBB9811-BC8B-4DAE-9247-1ABCE0B1B43D}  128500 2003-02-28  S12 4WX
# 11587348  {3D47873B-3F2F-45FC-B152-EB77F44B5DB8}   52000 2004-12-20  S12 4WX
# 11587349  {26F89041-F04E-48F7-927C-241E07DA289E}  250000 2004-09-24  S12 4WX
# 11587350  {B21A82DD-B935-4603-B64B-F06F55EEF058}  250000 2004-12-06  S12 4WX
# 11587351  {D91D8BE6-A90D-4129-948D-0AECDF6011CA}   43000 2004-04-07  S12 4WX
# 11587353  {3F5B6B4F-CA49-414F-B464-FBFA6973D723}  150000 2004-05-26  S12 4WX
# 11587358  {D76F4574-D2DF-40B1-827D-68D291A21C56}   74950 2007-11-19  S12 4WX
# 11587361  {3B0A3D33-7D5C-402C-8F41-7A0AB47E3F72}  250000 2007-04-17  S12 4WX
# 11587362  {8979629D-204F-46B0-B38B-98008758E6F7}  242500 2009-07-31  S12 4WX
# 11587363  {DB32B08A-D8A1-440A-9D03-429A71A59581}   80000 2010-05-24  S12 4WX
# 11587364  {4FA47CD4-D9BD-4B09-AC41-305E956B3029}  249950 2011-09-08  S12 4WX
# 11587367  {73F4F5DA-D397-455E-9755-2B060F365940}   39000 2013-03-08  S12 4WX
# 11587368  {21E5FEB7-1874-2439-E050-A8C06205342E}  170000 2013-10-25  S12 4WX
# 11587369  {CCF1B189-85C2-4DFA-9B64-FB8AC6BE9947}  124950 2014-11-28  S12 4WX
# 11587371  {31FB4C18-02E5-57B9-E050-A8C063053436}   89000 2016-04-08  S12 4WX
# 11587372  {5376B385-FC4C-34C1-E053-6B04A8C09FF6}   73500 2017-04-28  S12 4WX
# 11587373  {5F54B81D-C17C-2B45-E053-6B04A8C01FB0}  300000 2017-10-09  S12 4WX
# 11587374  {61D8894E-5ACF-3DE6-E053-6C04A8C01207}  295000 2017-11-24  S12 4WX
# 11587375  {726BF13B-54D8-0A46-E053-6C04A8C01D0D}  100000 2018-07-06  S12 4WX
# 11587376  {8F1B26BE-3779-53DB-E053-6C04A8C03649}   95500 2019-06-21  S12 4WX
# 11587377  {8355F009-7558-55C5-E053-6B04A8C0D090}   71500 2019-02-08  S12 4WX
