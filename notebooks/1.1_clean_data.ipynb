# %% [markdown]
# #### Clean Data Notebook
#
# 1. Rename the columns
# 2. Irrelevant columns
# 3. Duplicates
# 4. Null Values in relevant columns
# 5. Outliers
# 6. Map column values
# 7. Visualise and investigate

# %%
import pandas as pd

# %%
column_names = ['id', 'price', 'date', 'postcode', 
        'type', 'new_build', 'land', 'primary_address', 
        'secondary_address', 'street', 'locality', 'town_city', 
        'district', 'county', 'ppd', 'record' ]

df = pd.read_csv("../data/raw/pp-complete.csv", names = column_names, parse_dates = ['date'])

# %%
df.head(5)
# Out:
#                                        id  price       date  postcode type  \
# 0  {A42E2F04-2538-4A25-94C5-49E29C6C8FA8}  18500 1995-01-31   TQ1 1RY    F
# 1  {1BA349E3-2579-40D6-999E-49E2A25D2284}  73450 1995-10-09   L26 7XJ    D
# 2  {E5B50DCB-BC7A-4E54-B167-49E2A6B4148B}  59000 1995-03-31  BH12 2AE    D
# 3  {81E50116-D675-4B7F-9F8D-49E2B5D43271}  31000 1995-12-04  IP13 0DR    D
# 4  {B97455B9-75CB-40BB-A615-42C53683E143}  95000 1995-09-22  WS14 0BE    D
#
#   new_build land    primary_address secondary_address                street  \
# 0         N    L     VILLA PARADISO           FLAT 10  HIGHER WARBERRY ROAD
# 1         Y    F                  6               NaN           CATKIN ROAD
# 2         N    F                 28               NaN            ALDER ROAD
# 3         Y    F    NONSUCH COTTAGE               NaN            THE STREET
# 4         N    F  FOX COVER COTTAGE               NaN             HALL LANE
#
#     locality   town_city         district         county ppd record
# 0    TORQUAY     TORQUAY           TORBAY         TORBAY   A      A
# 1  LIVERPOOL   LIVERPOOL         KNOWSLEY     MERSEYSIDE   A      A
# 2      POOLE       POOLE            POOLE          POOLE   A      A
# 3  HACHESTON  WOODBRIDGE  SUFFOLK COASTAL        SUFFOLK   A      A
# 4  LICHFIELD   LICHFIELD        LICHFIELD  STAFFORDSHIRE   A      A

# %%
print(f"The data contains {df.shape[0]} rows.")
# Out:
# The data contains 25530306 rows.

# %%
df.dtypes
# Out:
# id                           object
# price                         int64
# date                 datetime64[ns]
# postcode                     object
# type                         object
# new_build                    object
# land                         object
# primary_address              object
# secondary_address            object
# street                       object
# locality                     object
# town_city                    object
# district                     object
# county                       object
# ppd                          object
# record                       object
# dtype: object

# %%
# Since we know the id's are not duplicated we can search excluding the id to see if any houses are entered twice.
duplicates = df.loc[:, 'price':'record'][df.loc[:, 'price':'record'].duplicated()]
print(f"The number of duplicates excluding id is {duplicates.shape[0]}")
# Out:
# The number of duplicates excluding id is 12452

# %%
#Lets perfom a quick check to verify there are actually duplicates (The answer should be two observations)
df[(df['postcode']=='N17 6YD') & (df['price']==12500)]
# Out:
#                                            id  price       date postcode type  \
# 90383  {2A289E9C-E447-CDC8-E050-A8C063054829}  12500 1995-02-06  N17 6YD    F
# 90384  {2A289E9C-E448-CDC8-E050-A8C063054829}  12500 1995-02-06  N17 6YD    F
#
#       new_build land primary_address secondary_address    street locality  \
# 90383         N    L              13               NaN  EVE ROAD      NaN
# 90384         N    L              13               NaN  EVE ROAD      NaN
#
#       town_city  district          county ppd record
# 90383    LONDON  HARINGEY  GREATER LONDON   A      A
# 90384    LONDON  HARINGEY  GREATER LONDON   A      A

# %%
# Lets drop the duplicates, keeping only the first instance. 
df_no_duplicates = df.drop_duplicates(subset = df.columns[1:] , keep = "first")

# %%
#Lets check the number of empty rows in each column. 
df_no_duplicates.isnull().sum()
# Out:
# id                          0
# price                       0
# date                        0
# postcode                40045
# type                        0
# new_build                   0
# land                        0
# primary_address          4191
# secondary_address    22539865
# street                 394033
# locality              8380064
# town_city                   0
# district                    0
# county                      0
# ppd                         0
# record                      0
# dtype: int64

# %%
df_empty_postcodes = df_no_duplicates[df_no_duplicates['postcode'].isnull()]

# %%
df_empty_postcodes.head()
# Out:
#                                           id   price       date postcode type  \
# 1976  {BEAA2DC6-B692-408E-A2A3-3BAEDDFCB145}   38950 1995-09-08      NaN    T
# 3882  {8E9EC4A0-D0DD-4707-8FD8-87474D269417}   60000 1995-10-16      NaN    D
# 5186  {06B58F72-089A-49E9-9F0F-3F500D8FC30B}   18500 1995-04-03      NaN    D
# 6435  {51EA43A4-017B-4A59-987B-BDD1EA19FE8E}  325000 1995-06-23      NaN    D
# 9123  {51F279F5-EF5F-46E1-BD8E-B6C4159D8FA7}   34000 1995-01-03      NaN    D
#
#      new_build land                 primary_address secondary_address  \
# 1976         Y    L                              66               NaN
# 3882         N    F                               3               NaN
# 5186         N    F                   TAN YR ORSEDD               NaN
# 6435         N    F                   THE GRANGE, 9               NaN
# 9123         N    F  PARNALL ROAD INDUSTRIAL ESTATE            UNIT 4
#
#                street         locality   town_city                   district  \
# 1976              NaN  MOSS HALL GROVE   LIVERPOOL                  LIVERPOOL
# 3882    PILGRIMS LANE          CHILHAM  CANTERBURY                    ASHFORD
# 5186              NaN         RHOSGOCH    RHOSGOCH  YNYS MON-ISLE OF ANGLESEY
# 6435  ORLEY FARM ROAD           HARROW      HARROW                     HARROW
# 9123     PARNALL ROAD          BRISTOL     BRISTOL                    BRISTOL
#
#               county ppd record
# 1976      MERSEYSIDE   A      A
# 3882            KENT   A      A
# 5186         GWYNEDD   A      A
# 6435  GREATER LONDON   A      A
# 9123            AVON   A      A

# %%
#Difficult decision - we can obviously try and workout a way to get the postcode using the roads but 
#that can prove to be too much work for us
#For now let us delete the observations with no postcode. 
df_complete = df_no_duplicates[df_no_duplicates['postcode'].notnull()]

# %%
df_complete.shape[0]
# Out:
# 25477809

# %%
#Lets view the range of the data (10 largest and 10 smallest)
df_complete.nlargest(n=10, columns='price')
# Out:
#                                               id      price       date  \
# 23109194  {582D0637-EE28-8F22-E053-6C04A8C01BAC}  594300000 2017-07-31
# 24152317  {666758D7-A512-3363-E053-6B04A8C0D74E}  569200000 2018-02-08
# 23286231  {7E86B6FB-BF88-458C-E053-6B04A8C0C84C}  448500000 2018-09-21
# 23941390  {773788C3-A146-2CE4-E053-6C04A8C05E57}  448300979 2018-08-17
# 23907865  {6DA0844A-CDA7-30F2-E053-6B04A8C05F3B}  415000000 2018-02-28
# 23907867  {6DA0844A-CDA9-30F2-E053-6B04A8C05F3B}  415000000 2018-02-28
# 24920018  {8CAC1318-F392-0253-E053-6B04A8C08E51}  411500000 2019-04-04
# 21860913  {55BDCAE6-DC9C-521D-E053-6B04A8C0DD7A}  370000000 2016-10-31
# 24324476  {98C75472-BCE7-72E9-E053-6B04A8C042F0}  337000000 2019-04-04
# 21862501  {55BDCAE6-C6B5-521D-E053-6B04A8C0DD7A}  330000000 2016-10-20
#
#           postcode type new_build land         primary_address  \
# 23109194   W1U 8EW    O         N    L                      55
# 24152317   W1J 7BT    O         N    F                       2
# 23286231   SE1 9JZ    O         N    F                      22
# 23941390   NE6 1AS    O         N    L                  UNIT 8
# 23907865   WS1 1RY    O         N    L                 37 - 39
# 23907867   WS1 1RY    O         N    F                      37
# 24920018  EC2V 7PG    O         N    L                      30
# 21860913  SW1H 0BG    O         N    F  NEW SCOTLAND YARD 8-10
# 24324476  EC4V 5AE    O         N    F                 35 - 45
# 21862501   TW6 2GD    O         N    L              TERMINAL 5
#
#                          secondary_address                             street  \
# 23109194                           UNIT 53                       BAKER STREET
# 24152317                               NaN                       STANHOPE ROW
# 23286231                               NaN                      SUMNER STREET
# 23941390                               NaN  HAWICK CRESCENT INDUSTRIAL ESTATE
# 23907865                               NaN                            DIGBETH
# 23907867                               NaN                            DIGBETH
# 24920018  FIRST, SEVENTH AND EIGHTH FLOORS                     GRESHAM STREET
# 21860913                               NaN                           BROADWAY
# 24324476                               NaN                        CARTER LANE
# 21862501                           SOFITEL                    WENTWORTH DRIVE
#
#                          locality            town_city             district  \
# 23109194                      NaN               LONDON  CITY OF WESTMINSTER
# 24152317                      NaN               LONDON  CITY OF WESTMINSTER
# 23286231                      NaN               LONDON            SOUTHWARK
# 23941390                      NaN  NEWCASTLE UPON TYNE  NEWCASTLE UPON TYNE
# 23907865                      NaN              WALSALL              WALSALL
# 23907867                      NaN              WALSALL              WALSALL
# 24920018                      NaN               LONDON       CITY OF LONDON
# 21860913                      NaN               LONDON  CITY OF WESTMINSTER
# 24324476                      NaN               LONDON       CITY OF LONDON
# 21862501  LONDON HEATHROW AIRPORT             HOUNSLOW           HILLINGDON
#
#                   county ppd record
# 23109194  GREATER LONDON   B      A
# 24152317  GREATER LONDON   B      A
# 23286231  GREATER LONDON   B      A
# 23941390   TYNE AND WEAR   B      A
# 23907865   WEST MIDLANDS   B      A
# 23907867   WEST MIDLANDS   B      A
# 24920018  GREATER LONDON   B      A
# 21860913  GREATER LONDON   B      A
# 24324476  GREATER LONDON   B      A
# 21862501  GREATER LONDON   B      A

# %% [markdown]
# I think we can all admit - we can't afford these kind of houses. I really wanted to make this project for a normal ordinary house. So what I really want to do is to cap the data to just houses that are less than a million.

# %%
# Lets View the cheaperst houses. 
df_complete.nsmallest(n=10, columns='price')
# Out:
#                                             id  price       date  postcode  \
# 95948   {2A289E9D-31D2-CDC8-E050-A8C063054829}      1 1995-04-18  EX34 9JU
# 490887  {2A289E9F-B709-CDC8-E050-A8C063054829}      1 1995-08-04   M30 9AF
# 520198  {2A289E9E-EB2B-CDC8-E050-A8C063054829}      1 1995-09-11   KT1 4DQ
# 523780  {2A289E9E-AEB6-CDC8-E050-A8C063054829}      1 1995-03-17    W3 9RN
# 524227  {2A289E9E-EE9B-CDC8-E050-A8C063054829}      1 1995-12-08   SG5 4LW
# 552204  {2A289E9F-77B4-CDC8-E050-A8C063054829}      1 1995-12-08  SN12 7RR
# 566664  {2A289E9D-D2C7-CDC8-E050-A8C063054829}      1 1995-05-12  OX14 1EL
# 568492  {2A289E9D-E7BD-CDC8-E050-A8C063054829}      1 1995-02-10  SW11 1HT
# 572479  {2A289E9D-EB15-CDC8-E050-A8C063054829}      1 1995-01-13  BA21 5TQ
# 579188  {2A289E9D-1927-CDC8-E050-A8C063054829}      1 1995-01-12   TQ1 4BE
#
#        type new_build land primary_address secondary_address  \
# 95948     T         N    F               5               NaN
# 490887    T         N    F               8               NaN
# 520198    T         N    F              98               NaN
# 523780    S         N    F               3               NaN
# 524227    S         N    F              34               NaN
# 552204    S         N    F              19               NaN
# 566664    S         N    L              19               NaN
# 568492    T         N    F             16A               NaN
# 572479    S         N    F               1               NaN
# 579188    T         N    F             147               NaN
#
#                   street      locality             town_city  \
# 95948     APSLEY TERRACE           NaN            ILFRACOMBE
# 490887    DOUGHTY AVENUE        ECCLES            MANCHESTER
# 520198       HIGH STREET  HAMPTON WICK  KINGSTON UPON THAMES
# 523780    HILLCREST ROAD         ACTON                LONDON
# 524227  UPPERSTONE CLOSE      STOTFOLD               HITCHIN
# 552204     MALVERN CLOSE           NaN              MELKSHAM
# 566664   FITZHARRYS ROAD           NaN              ABINGDON
# 568492     CHIVALRY ROAD           NaN                LONDON
# 572479         HILL VIEW       MUDFORD                YEOVIL
# 579188    LYMINGTON ROAD           NaN               TORQUAY
#
#                     district                county ppd record
# 95948            NORTH DEVON                 DEVON   A      A
# 490887               SALFORD    GREATER MANCHESTER   A      A
# 520198  RICHMOND UPON THAMES        GREATER LONDON   A      A
# 523780                EALING        GREATER LONDON   A      A
# 524227  CENTRAL BEDFORDSHIRE  CENTRAL BEDFORDSHIRE   A      A
# 552204             WILTSHIRE             WILTSHIRE   A      A
# 566664   VALE OF WHITE HORSE           OXFORDSHIRE   A      A
# 568492            WANDSWORTH        GREATER LONDON   A      A
# 572479        SOUTH SOMERSET              SOMERSET   A      A
# 579188                TORBAY                TORBAY   A      A

# %%
# From this I think we should only observe houses that are between 10,000 and 1,000,000
df_price_cut = df_complete[(df_complete['price']<=1000000) & (df['price']>=10000)].reset_index(drop = True)
# Out:
# <ipython-input-20-3d3e9660becf>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_price_cut = df_complete[(df_complete['price']<=1000000) & (df['price']>=10000)].reset_index(drop = True)

# %%
perc_reduction = ((df_complete.shape[0] - df_price_cut.shape[0])/df_complete.shape[0])*100
print(f"filtered out {perc_reduction} % of data")
# Out:
# filtered out 1.0750374963561427 % of data

# %%
df_price_cut.to_csv("../data/processed/house_1_price_cut.csv", index = False)

# %%
# Going forward we need to add some columns

# %%
new_build = {'Y': 1,'N': 0}
df_price_cut.new_build = [new_build[item] for item in df_price_cut.new_build]
df_price_cut['year'] = df_price_cut['date'].dt.year
df_price_cut['month'] = df_price_cut['date'].dt.year
df_price_cut['month_year'] = df_price_cut['date'].astype('datetime64[M]')

# %%
df_price_cut.head()
# Out:
#                                        id  price       date  postcode type  \
# 0  {A42E2F04-2538-4A25-94C5-49E29C6C8FA8}  18500 1995-01-31   TQ1 1RY    F
# 1  {1BA349E3-2579-40D6-999E-49E2A25D2284}  73450 1995-10-09   L26 7XJ    D
# 2  {E5B50DCB-BC7A-4E54-B167-49E2A6B4148B}  59000 1995-03-31  BH12 2AE    D
# 3  {81E50116-D675-4B7F-9F8D-49E2B5D43271}  31000 1995-12-04  IP13 0DR    D
# 4  {B97455B9-75CB-40BB-A615-42C53683E143}  95000 1995-09-22  WS14 0BE    D
#
#    new_build land    primary_address secondary_address                street  \
# 0          0    L     VILLA PARADISO           FLAT 10  HIGHER WARBERRY ROAD
# 1          1    F                  6               NaN           CATKIN ROAD
# 2          0    F                 28               NaN            ALDER ROAD
# 3          1    F    NONSUCH COTTAGE               NaN            THE STREET
# 4          0    F  FOX COVER COTTAGE               NaN             HALL LANE
#
#     locality   town_city         district         county ppd record  year  \
# 0    TORQUAY     TORQUAY           TORBAY         TORBAY   A      A  1995
# 1  LIVERPOOL   LIVERPOOL         KNOWSLEY     MERSEYSIDE   A      A  1995
# 2      POOLE       POOLE            POOLE          POOLE   A      A  1995
# 3  HACHESTON  WOODBRIDGE  SUFFOLK COASTAL        SUFFOLK   A      A  1995
# 4  LICHFIELD   LICHFIELD        LICHFIELD  STAFFORDSHIRE   A      A  1995
#
#    month month_year
# 0   1995 1995-01-01
# 1   1995 1995-10-01
# 2   1995 1995-03-01
# 3   1995 1995-12-01
# 4   1995 1995-09-01

# %%
#Adjust price to inflation
df_multiplier = pd.read_csv("../data/raw/inflation_multiplier.csv", usecols = ['Year', 'Multiplier'], dtype = {'Year': 'int64', 'Multiplier': 'float64'})
df_multiplier.columns =['year', 'multiplier']

# %%
df_multiplier.dtypes
# Out:
# year            int64
# multiplier    float64
# dtype: object

# %%
df_house_data = pd.merge(df_price_cut, df_multiplier, on='year')

# %%
df_house_data['adjusted_price'] = df_house_data['price'] * df_house_data['multiplier']

# %%
df_house_data.head()
# Out:
#                                        id  price       date  postcode type  \
# 0  {A42E2F04-2538-4A25-94C5-49E29C6C8FA8}  18500 1995-01-31   TQ1 1RY    F
# 1  {1BA349E3-2579-40D6-999E-49E2A25D2284}  73450 1995-10-09   L26 7XJ    D
# 2  {E5B50DCB-BC7A-4E54-B167-49E2A6B4148B}  59000 1995-03-31  BH12 2AE    D
# 3  {81E50116-D675-4B7F-9F8D-49E2B5D43271}  31000 1995-12-04  IP13 0DR    D
# 4  {B97455B9-75CB-40BB-A615-42C53683E143}  95000 1995-09-22  WS14 0BE    D
#
#    new_build land    primary_address secondary_address                street  \
# 0          0    L     VILLA PARADISO           FLAT 10  HIGHER WARBERRY ROAD
# 1          1    F                  6               NaN           CATKIN ROAD
# 2          0    F                 28               NaN            ALDER ROAD
# 3          1    F    NONSUCH COTTAGE               NaN            THE STREET
# 4          0    F  FOX COVER COTTAGE               NaN             HALL LANE
#
#    ...   town_city         district         county ppd record  year  month  \
# 0  ...     TORQUAY           TORBAY         TORBAY   A      A  1995   1995
# 1  ...   LIVERPOOL         KNOWSLEY     MERSEYSIDE   A      A  1995   1995
# 2  ...       POOLE            POOLE          POOLE   A      A  1995   1995
# 3  ...  WOODBRIDGE  SUFFOLK COASTAL        SUFFOLK   A      A  1995   1995
# 4  ...   LICHFIELD        LICHFIELD  STAFFORDSHIRE   A      A  1995   1995
#
#    month_year multiplier  adjusted_price
# 0  1995-01-01       2.01         37185.0
# 1  1995-10-01       2.01        147634.5
# 2  1995-03-01       2.01        118590.0
# 3  1995-12-01       2.01         62310.0
# 4  1995-09-01       2.01        190950.0
#
# [5 rows x 21 columns]

# %%
df_house_data.nlargest(n=10, columns='adjusted_price')
# Out:
#                                             id    price       date  postcode  \
# 66420   {48F1260A-F447-491D-B627-C33F9E1D5010}  1000000 1995-06-27  SW10 9SP
# 148663  {41FC4910-C5D6-4AC3-B073-C58680CC51F4}  1000000 1995-09-08    W8 6PR
# 227300  {D7A13F02-6FBD-439E-8404-169FE5808583}  1000000 1995-12-07   SW7 2NP
# 259581  {5F56B504-1472-46EA-9F72-B57E636EF71C}  1000000 1995-09-15  NW11 6XB
# 304459  {100CE525-FB27-43F5-9779-308446676973}  1000000 1995-05-26   SL6 2NA
# 337083  {3588B03D-6A99-478F-B75B-62E89BDF0593}  1000000 1995-06-08   NW8 9DX
# 355874  {31A6FB6C-9BE1-475D-8752-DA4FB10FA036}  1000000 1995-08-30   NW8 9BW
# 473462  {EA97603D-9036-4813-AEBA-B0BB8A3E8E4E}  1000000 1995-06-21  GU34 5NQ
# 521368  {F697DE00-EEEE-41C1-9E5E-38F71B30F195}  1000000 1995-03-17   BR6 8LL
# 529507  {2A289EA1-877A-CDC8-E050-A8C063054829}  1000000 1995-01-26  SW15 2BZ
#
#        type  new_build land   primary_address secondary_address  \
# 66420     T          0    F                 9               NaN
# 148663    S          0    F                18               NaN
# 227300    T          0    L                 4               NaN
# 259581    F          0    L                34               NaN
# 304459    D          0    F      CHUFFS HOUSE               NaN
# 337083    T          0    F                21               NaN
# 355874    F          1    L                20          FLAT 127
# 473462    D          0    F  HATTINGLEY HOUSE               NaN
# 521368    D          0    F                 8               NaN
# 529507    D          0    F                 4               NaN
#
#                   street  ...   town_city                district  \
# 66420        PRIORY WALK  ...      LONDON  KENSINGTON AND CHELSEA
# 148663  SCARSDALE VILLAS  ...      LONDON  KENSINGTON AND CHELSEA
# 227300   PELHAM CRESCENT  ...      LONDON  KENSINGTON AND CHELSEA
# 259581     WILDWOOD ROAD  ...      LONDON                  BARNET
# 304459    MONEYROW GREEN  ...  MAIDENHEAD  WINDSOR AND MAIDENHEAD
# 337083    ABERCORN PLACE  ...      LONDON     CITY OF WESTMINSTER
# 355874        ABBEY ROAD  ...      LONDON     CITY OF WESTMINSTER
# 473462   HATTINGLEY ROAD  ...       ALTON          EAST HAMPSHIRE
# 521368       PARK AVENUE  ...   ORPINGTON                 BROMLEY
# 529507     CARLTON DRIVE  ...      LONDON              WANDSWORTH
#
#                         county ppd record  year  month  month_year multiplier  \
# 66420           GREATER LONDON   A      A  1995   1995  1995-06-01       2.01
# 148663          GREATER LONDON   A      A  1995   1995  1995-09-01       2.01
# 227300          GREATER LONDON   A      A  1995   1995  1995-12-01       2.01
# 259581          GREATER LONDON   A      A  1995   1995  1995-09-01       2.01
# 304459  WINDSOR AND MAIDENHEAD   A      A  1995   1995  1995-05-01       2.01
# 337083          GREATER LONDON   A      A  1995   1995  1995-06-01       2.01
# 355874          GREATER LONDON   A      A  1995   1995  1995-08-01       2.01
# 473462               HAMPSHIRE   A      A  1995   1995  1995-06-01       2.01
# 521368          GREATER LONDON   A      A  1995   1995  1995-03-01       2.01
# 529507          GREATER LONDON   A      A  1995   1995  1995-01-01       2.01
#
#         adjusted_price
# 66420        2010000.0
# 148663       2010000.0
# 227300       2010000.0
# 259581       2010000.0
# 304459       2010000.0
# 337083       2010000.0
# 355874       2010000.0
# 473462       2010000.0
# 521368       2010000.0
# 529507       2010000.0
#
# [10 rows x 21 columns]

# %%
df_house_data.to_csv("../data/processed/house_2_adjusted_data.csv", index = False)

# %%
df_multiple_transactions = df_house_data.loc[:, 'postcode':'county'][df_house_data.loc[:, 'postcode':'county'].duplicated()]

# %%
df_multiple_transactions.shape
# Out:
# (6795597, 11)

# %%
# Lets drop the duplicates, keeping only the first instance. 
df_house_data_ordered = df_house_data.sort_values(by=['date'])
df_house_last_sale = df_house_data_ordered.drop_duplicates(subset = df_house_data_ordered.columns[3:14] ,keep = "last")

# %%
df_house_last_sale.shape
# Out:
# (18408316, 21)

# %%
df_house_last_sale.to_csv("../data/processed/house_3_last_sale.csv", index = False)
